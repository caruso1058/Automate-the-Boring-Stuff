# %% [markdown]
# # Functions

# %%
def hello():
    print('Howdy!')
    print('Howdy!!')
    print('Hello there!')
hello()
# Out:
# Howdy!
# Howdy!!
# Hello there!

# %%
def hello(name):
    print('Hello, ' + name)
hello('Alice')
# Out:
# Hello, Alice

# %%
import random
def get_answers(answer_number):
    if answer_number == 1:
        return 'It is certain'
    elif answer_number == 2:
        return 'It is decidedly so'
    elif answer_number == 3:
        return 'Yes'
    elif answer_number == 4:
        return 'Reply Hazy, try again'
    elif answer_number == 5:
        return 'Ask again later'
    elif answer_number == 6:
        return 'Concentrate and ask again'
    elif answer_number == 7:
        return 'My reply is no'
    elif answer_number == 8:
        return 'Very doubtful'
    
r = random.randint(1,8)
fortune = get_answers(r) 
print(fortune,'-', 'the random number generated is', r )
# Out:
# Ask again later - the random number generated is 5

# %% [markdown]
# # The Call Stack:

# %%
def a():
    print ('a() returns')
    b()
    d()
    print('a() returns')
    
def b():
    print('b() starts')
    c()
    print('b() returns')

def c():
    print('c() starts')
    print('c() returns')
    
def d():
    print('d() starts')
    print('d() returns')
    
a()
# Out:
# a() returns
# b() starts
# c() starts
# c() returns
# b() returns
# d() starts
# d() returns
# a() returns

# %% [markdown]
# # Exception Errors

# %%
def spam(divide_by):
    try:
        return 42 / divide_by
    except ZeroDivisionError:
        print('Error: Invalid Argument')
print(spam (2))
print(spam (12))
print(spam (0))
print(spam (1))
# Out:
# 21.0
# 3.5
# Error: Invalid Argument
# None
# 42.0

# %%
#Or just use try to stop at the error

def spam(divide_by):
    return 42 / divide_by
try:
    print(spam (2))
    print(spam (12))
    print(spam (0))
    print(spam (1))
except ZeroDivisionError:
    print('oh well')
# Out:
# 21.0
# 3.5
# oh well

# %% [markdown]
# # Lists

# %%
cat_names = []
while True:
    print('Enter the name of your cat ' + str(len(cat_names) + 1) + ' (Or enter nothing to stop):')
    name = input()
    if name == '':
        break
    cat_names = cat_names + [name] 
print ('The cat names are:')
for name in cat_names:
    print(' ' + name)
# Out:
# Enter the name of your cat 1 (Or enter nothing to stop):
# Jules
# Enter the name of your cat 2 (Or enter nothing to stop):
# Lauren
# Enter the name of your cat 3 (Or enter nothing to stop):
#
# The cat names are:
#  Jules
#  Lauren

# %%
for i in range (4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
supplies = ['pens', 'staplers', 'flamethrowers', 'binders']
for i in range(len(supplies)):
    print('Index ' + str(i) + ' in supplies is: ' + supplies[i])
# Out:
# Index 0 in supplies is: pens
# Index 1 in supplies is: staplers
# Index 2 in supplies is: flamethrowers
# Index 3 in supplies is: binders

# %% [markdown]
# # The in Operator

# %%
'howdy' in ['hello', 'hi', 'howdy', 'heyas']
# Out:
# True

# %%
spam = ['hello', 'hi', 'howdy', 'heyas']
'cat' in spam
# Out:
# False

# %%
'cat' not in spam
# Out:
# True

# %%
# Program to see if name is in list of pets

my_pets = ['Zophie', 'Pooka', 'Fat-Tail']
print('Enter a pet name:')
name = input()
if name not in my_pets:
    print('I do not have a pet named ' + name)
else:
    print(name + ' is my pet.')
# Out:
# Enter a pet name:
# jeff
# I do not have a pet named jeff

# %%
#enumerate function returns the index of the item in a list along with the list item

supplies = ['pens', 'staplers', 'flamethrowers', 'binders']
for index, item in enumerate(supplies):
    print('Index ' + str(index) + ' in supplies is:' + item)
# Out:
# Index 0 in supplies is:pens
# Index 1 in supplies is:staplers
# Index 2 in supplies is:flamethrowers
# Index 3 in supplies is:binders

# %%
# make random choices from a list

import random
pets = ['Dog', 'Cat', 'Moose']
random.choice(pets)
# Out:
# 'Dog'

# %%
#adding to a variable

spam = 42
spam = spam + 1
spam
# Out:
# 43

# %%
#OR
spam = 42
spam += 1
spam
# Out:
# 43

# %%
#Sort reverse order

pets.sort(reverse = True)

# %%
pets
# Out:
# ['Moose', 'Dog', 'Cat']

# %%
# A more elegant Magic 8 Ball Program

import random
messages = ['It is certain', 
           'It is decidedly so', 
           'Yes, definitely', 
           'Reply is hazy, try again',
           'Ask again later',
           'Concentrate and ask again',
           'My reply is no',
           'Outlook not so good',
           'Very doubtful']

print(messages[random.randint(0,len(messages) - 1)])
# Out:
# Very doubtful

# %%
print(id('Howdy'))
print(id(messages))
# Out:
# 2799953175408
# 2799953522632

# %%
#Make copies of a list without altering the origional list
#if the list you are copying needs to be copied then use copy.deepcopy()

import copy
spam = ['A', 'B', 'C', 'D', 'E']
id(spam)
# Out:
# 2799953859400

# %%
cheese = copy.copy(spam)

# %%
id(cheese)
# Out:
# 2799953555656

# %%
cheese[1] = 42
cheese
# Out:
# ['A', 42, 'C', 'D', 'E']

# %%
spam
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
#Conway's game of life

import random, time, copy

width = 60
height = 20
#Create a list of lists for the cells

nextCells = []
for x in range(width):
    column = [] #create a new column
    for y in range(height):
        if random.randint(0,1) == 0:
            column.append('#') #add a living cell
        else:
            column.append(' ') #add a dead cell
    nextCells.append(column)
        
while True: #main program loop
    print('\n\n\n\n\n') #seperates each step with new lines
    currentCells = copy.deepcopy(nextCells)
    
#Print current cells on screen    
for y in range(height):
    for x in range(width):
        print(currentCells[x][y], end='') #Print the # or space
    print() # print a new line at the end of the row
#Calculate the next step's cell based on the current step's cell

for x in range(width):
    for y in range(height):
        #get neighbor coordinates 
        #'%Width' ensures leftCoor is always between 0 and width - 1
        leftCoord = (x - 1) % width
        rightCoord = (x + 1) % width
        aboveCoord = (y - 1) % height
        belowCoord = (y + 1) % height
        
        #COUNT the nummber of living neighbors
        numNeighbors = 0
        if currentCells [leftCoord] [aboveCoord] == '#':
            numNeighbors += 1 #Top-left neighbor is alive.
        if currentCells [x] [aboveCoord] == '#':
            numNeighbors += 1
        if currentCells [rightCoord] [aboveCoord] == '#':
            numNeighbors += 1
        if currentCells [leftCoord] [y] == '#':
            numNeighbors += 1
        if currentCells [rightCoord] [y] == '#':
            numNeighbors += 1
        if currentCells [leftCoord] [belowCoord] == '#':
            numNeighbors += 1
        if currentCells [x] [belowCoord] == '#':
            numNeighbors += 1
        if currentCells [rightCoord] [belowCoord] == '#':
            numNeighbors += 1
            
        if currentCells[x][y] == '#' and (numNeighbors == 2 or numNeighbors == 3):
            nextCells [x][y] = '#'
        elif currentCells [x][y] == ' ' and numNeighbors == 3:
            nextCells[x][y] = '#'
        else:
            nextCells[x][y] = ' '
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-48a402315cd3> in <module>
#      18
#      19 while True: #main program loop
# ---> 20     print('\n\n\n\n\n') #seperates each step with new lines
#      21     currentCells = copy.deepcopy(nextCells)
#      22
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# ...
